# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('homework.csv')

# %%
df.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
df.plot(kind='scatter', x='crim', y='medv', figsize=(16, 9))
# Out:
# <AxesSubplot:xlabel='crim', ylabel='medv'>

# %%
df.plot(kind='scatter', x='rm', y='medv', figsize=(16, 9))
# Out:
# <AxesSubplot:xlabel='rm', ylabel='medv'>

# %%
df.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
x = df[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
       'tax', 'ptratio', 'black', 'lstat']]
y = df['medv']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model =LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
surv = X_test.copy()
surv['y_pred'] = y_pred
surv['y_test'] = y_test
surv
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 25   0.15936   0.0   6.91     0  0.448  6.211   6.5  5.7209    3  233
# 309  4.03841   0.0  18.10     0  0.532  6.229  90.7  3.0993   24  666
# 73   0.12802   0.0   8.56     0  0.520  6.474  97.1  2.4329    5  384
# 195  0.03615  80.0   4.95     0  0.411  6.630  23.4  5.1167    4  245
# 57   0.05059   0.0   4.49     0  0.449  6.389  48.0  4.7794    3  247
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 280  5.58107   0.0  18.10     0  0.713  6.436  87.9  2.3158   24  666
# 3    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 77   0.13158   0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432
# 311  8.05579   0.0  18.10     0  0.584  5.427  95.4  2.4298   24  666
# 60   0.07151   0.0   4.49     0  0.449  6.121  56.8  3.7476    3  247
#
#      ptratio   black  lstat     y_pred  y_test
# 25      17.9  394.46   7.44  24.501415    24.7
# 309     20.2  395.33  12.87  23.352186    19.6
# 73      20.9  395.24  12.27  22.560818    19.8
# 195     19.2  396.90   4.70  33.271037    27.9
# 57      18.5  396.90   9.62  24.391792    23.9
# ..       ...     ...    ...        ...     ...
# 280     20.2  100.19  16.22  18.183570    14.3
# 3       18.7  396.90   5.33  27.312914    36.2
# 77      17.8  393.30  12.04  22.979136    21.2
# 311     20.2  352.58  18.14  17.135834    13.8
# 60      18.5  395.15   8.44  26.030890    22.2
#
# [67 rows x 15 columns]

# %%
mean_squared_error (y_train, model.predict(X_train))
# Out:
# 22.584539086001996

# %%
mean_squared_error (y_test, model.predict(X_test))
# Out:
# 23.486735195425826
